# %% [markdown]
# The data we will be working with is the Maryland crashes dataset taken from https://opendata.maryland.gov/. This dataset consists of crashes that occured in the Maryland state from January 2015 to September 2021. This dataset has three sub-datasets which are:
#
# Dataset-1: Maryland Statewide Vehicle Crashes:  <br>
# https://opendata.maryland.gov/Public-Safety/Maryland-Statewide-Vehicle-Crashes/65du-s3qu
#
# Dataset-2: Person Details:  <br>
# https://opendata.maryland.gov/Public-Safety/Maryland-Statewide-Vehicle-Crashes-Person-Details-/py4c-dicf
#
# Dataset-3: Vehicle Details:  <br>
# https://opendata.maryland.gov/Public-Safety/Maryland-Statewide-Vehicle-Crashes-Vehicle-Details/mhft-5t5y
#
# <br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.cm as cm
from statsmodels.stats.weightstats import ztest

# %% [markdown]
# - The three datasets crashes, persons and vehicles are cleaned and understood before importing it here.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
crashes = pd.read_csv('C:/Users/madas/Desktop/Final Project 601/Maryland_Statewide_Vehicle_Crashes.csv',low_memory=False)
persons = pd.read_csv('C:/Users/madas/Desktop/Final Project 601/persons_refined.csv',low_memory=False)
vehicles = pd.read_csv('C:/Users/madas/Desktop/Final Project 601/vehicles_refined.csv',low_memory=False)

# %%
crashes.head().T
# Out:
#                                                      0  \
# YEAR                                              2020
# QUARTER                                             Q2
# LIGHT_DESC                                    Daylight
# LIGHT_CODE                                         1.0
# COUNTY_DESC                                  Baltimore
# COUNTY_NO                                          3.0
# MUNI_DESC                                          NaN
# MUNI_CODE                                          NaN
# JUNCTION_DESC                                      NaN
# JUNCTION_CODE                                      NaN
# COLLISION_TYPE_DESC                              Other
# COLLISION_TYPE_CODE                                 88
# SURF_COND_DESC                                     NaN
# SURF_COND_CODE                                     NaN
# LANE_DESC                                          NaN
# LANE_CODE                                          NaN
# RD_COND_DESC                                       NaN
# RD_COND_CODE                                       NaN
# RD_DIV_DESC                                        NaN
# RD_DIV_CODE                                        NaN
# FIX_OBJ_DESC                            Not Applicable
# FIX_OBJ_CODE                                       0.0
# REPORT_NO                                   AE58770052
# REPORT_TYPE                      Property Damage Crash
# WEATHER_DESC                            Not Applicable
# WEATHER_CODE                                       0.0
# ACC_DATE                                      20200618
# ACC_TIME                                      15:15:00
# LOC_CODE                                           NaN
# SIGNAL_FLAG_DESC                                    No
# SIGNAL_FLAG                                          N
# C_M_ZONE_FLAG                                        N
# AGENCY_CODE                                     BACOPD
# AREA_CODE                                          UNK
# HARM_EVENT_DESC1                        Parked Vehicle
# HARM_EVENT_CODE1                                   2.0
# HARM_EVENT_DESC2                        Not Applicable
# HARM_EVENT_CODE2                                   0.0
# RTE_NO                                             NaN
# ROUTE_TYPE_CODE                                    NaN
# RTE_SUFFIX                                         NaN
# LOG_MILE                                           NaN
# LOGMILE_DIR_FLAG_DESC                              NaN
# LOGMILE_DIR_FLAG                                   NaN
# MAINROAD_NAME                                      NaN
# DISTANCE                                           NaN
# FEET_MILES_FLAG_DESC                               NaN
# FEET_MILES_FLAG                                    NaN
# DISTANCE_DIR_FLAG                                  NaN
# REFERENCE_NO                                       NaN
# REFERENCE_TYPE_CODE                                NaN
# REFERENCE_SUFFIX                                   NaN
# REFERENCE_ROAD_NAME                                NaN
# LATITUDE                                     39.277263
# LONGITUDE                                   -76.503693
# LOCATION               POINT (-76.5036932 39.27726285)
#
#                                                               1  \
# YEAR                                                       2020
# QUARTER                                                      Q2
# LIGHT_DESC                                                  NaN
# LIGHT_CODE                                                 6.02
# COUNTY_DESC                                      Baltimore City
# COUNTY_NO                                                  24.0
# MUNI_DESC                                                   NaN
# MUNI_CODE                                                   NaN
# JUNCTION_DESC                                  Non Intersection
# JUNCTION_CODE                                               1.0
# COLLISION_TYPE_DESC                                       Other
# COLLISION_TYPE_CODE                                          88
# SURF_COND_DESC                                              Dry
# SURF_COND_CODE                                              2.0
# LANE_DESC                                        Left Turn Lane
# LANE_CODE                                                   2.0
# RD_COND_DESC                                         No Defects
# RD_COND_CODE                                                1.0
# RD_DIV_DESC                                  One-way Trafficway
# RD_DIV_CODE                                                 2.0
# FIX_OBJ_DESC                                         Other Pole
# FIX_OBJ_CODE                                               10.0
# REPORT_NO                                            ADJ984001J
# REPORT_TYPE                                        Injury Crash
# WEATHER_DESC                                                NaN
# WEATHER_CODE                                               7.01
# ACC_DATE                                               20200430
# ACC_TIME                                               06:39:00
# LOC_CODE                                                   1003
# SIGNAL_FLAG_DESC                                            Yes
# SIGNAL_FLAG                                                   Y
# C_M_ZONE_FLAG                                                 N
# AGENCY_CODE                                           BALTIMORE
# AREA_CODE                                                   UNK
# HARM_EVENT_DESC1                                  Other Vehicle
# HARM_EVENT_CODE1                                            1.0
# HARM_EVENT_DESC2                                  Other Vehicle
# HARM_EVENT_CODE2                                            1.0
# RTE_NO                                                      NaN
# ROUTE_TYPE_CODE                                             NaN
# RTE_SUFFIX                                                  NaN
# LOG_MILE                                                    0.0
# LOGMILE_DIR_FLAG_DESC                                       NaN
# LOGMILE_DIR_FLAG                                            NaN
# MAINROAD_NAME                                    CHARLES STREET
# DISTANCE                                                    2.0
# FEET_MILES_FLAG_DESC                                      Miles
# FEET_MILES_FLAG                                               M
# DISTANCE_DIR_FLAG                                             N
# REFERENCE_NO                                                NaN
# REFERENCE_TYPE_CODE                                         NaN
# REFERENCE_SUFFIX                                            NaN
# REFERENCE_ROAD_NAME                                   NORTH AVE
# LATITUDE                                              39.311025
# LONGITUDE                                            -76.616429
# LOCATION               POINT (-76.616429453205 39.311024794431)
#
#                                                               2  \
# YEAR                                                       2020
# QUARTER                                                      Q2
# LIGHT_DESC                                             Daylight
# LIGHT_CODE                                                  1.0
# COUNTY_DESC                                          Montgomery
# COUNTY_NO                                                  15.0
# MUNI_DESC                                                   NaN
# MUNI_CODE                                                   NaN
# JUNCTION_DESC                                               NaN
# JUNCTION_CODE                                               NaN
# COLLISION_TYPE_DESC                                       Other
# COLLISION_TYPE_CODE                                          88
# SURF_COND_DESC                                              NaN
# SURF_COND_CODE                                              NaN
# LANE_DESC                                                   NaN
# LANE_CODE                                                   NaN
# RD_COND_DESC                                                NaN
# RD_COND_CODE                                                NaN
# RD_DIV_DESC                                                 NaN
# RD_DIV_CODE                                                 NaN
# FIX_OBJ_DESC                                     Not Applicable
# FIX_OBJ_CODE                                                0.0
# REPORT_NO                                            EJ7878001D
# REPORT_TYPE                                        Injury Crash
# WEATHER_DESC                                                NaN
# WEATHER_CODE                                               6.01
# ACC_DATE                                               20200504
# ACC_TIME                                               09:46:00
# LOC_CODE                                                  54222
# SIGNAL_FLAG_DESC                                             No
# SIGNAL_FLAG                                                   N
# C_M_ZONE_FLAG                                                 N
# AGENCY_CODE                                        GAITHERSBURG
# AREA_CODE                                                   UNK
# HARM_EVENT_DESC1                                     Pedestrian
# HARM_EVENT_CODE1                                            3.0
# HARM_EVENT_DESC2                                 Not Applicable
# HARM_EVENT_CODE2                                            0.0
# RTE_NO                                                      NaN
# ROUTE_TYPE_CODE                                             NaN
# RTE_SUFFIX                                                  NaN
# LOG_MILE                                                    NaN
# LOGMILE_DIR_FLAG_DESC                                       NaN
# LOGMILE_DIR_FLAG                                            NaN
# MAINROAD_NAME                                               NaN
# DISTANCE                                                    NaN
# FEET_MILES_FLAG_DESC                                        NaN
# FEET_MILES_FLAG                                             NaN
# DISTANCE_DIR_FLAG                                           NaN
# REFERENCE_NO                                                NaN
# REFERENCE_TYPE_CODE                                         NaN
# REFERENCE_SUFFIX                                            NaN
# REFERENCE_ROAD_NAME                                         NaN
# LATITUDE                                               39.14068
# LONGITUDE                                            -77.193413
# LOCATION               POINT (-77.193412729561 39.140680249069)
#
#                                                                 3  \
# YEAR                                                         2017
# QUARTER                                                        Q2
# LIGHT_DESC                                               Daylight
# LIGHT_CODE                                                    1.0
# COUNTY_DESC                                        Baltimore City
# COUNTY_NO                                                    24.0
# MUNI_DESC                                                     NaN
# MUNI_CODE                                                     NaN
# JUNCTION_DESC                                                 NaN
# JUNCTION_CODE                                                 NaN
# COLLISION_TYPE_DESC                                Single Vehicle
# COLLISION_TYPE_CODE                                            17
# SURF_COND_DESC                                                NaN
# SURF_COND_CODE                                                NaN
# LANE_DESC                                                     NaN
# LANE_CODE                                                     NaN
# RD_COND_DESC                                                  NaN
# RD_COND_CODE                                                  NaN
# RD_DIV_DESC                                                   NaN
# RD_DIV_CODE                                                   NaN
# FIX_OBJ_DESC                                       Not Applicable
# FIX_OBJ_CODE                                                  0.0
# REPORT_NO                                              ADI7910042
# REPORT_TYPE                                          Injury Crash
# WEATHER_DESC                                                Other
# WEATHER_CODE                                                 88.0
# ACC_DATE                                                 20170507
# ACC_TIME                                                 10:39:00
# LOC_CODE                                                 CAD#0830
# SIGNAL_FLAG_DESC                                              Yes
# SIGNAL_FLAG                                                     Y
# C_M_ZONE_FLAG                                                   N
# AGENCY_CODE                                             BALTIMORE
# AREA_CODE                                                     UNK
# HARM_EVENT_DESC1                                              NaN
# HARM_EVENT_CODE1                                              3.0
# HARM_EVENT_DESC2                                   Not Applicable
# HARM_EVENT_CODE2                                              0.0
# RTE_NO                                                        NaN
# ROUTE_TYPE_CODE                                               NaN
# RTE_SUFFIX                                                    NaN
# LOG_MILE                                                      NaN
# LOGMILE_DIR_FLAG_DESC                                         NaN
# LOGMILE_DIR_FLAG                                              NaN
# MAINROAD_NAME                                                 NaN
# DISTANCE                                                      NaN
# FEET_MILES_FLAG_DESC                                          NaN
# FEET_MILES_FLAG                                               NaN
# DISTANCE_DIR_FLAG                                             NaN
# REFERENCE_NO                                                  NaN
# REFERENCE_TYPE_CODE                                           NaN
# REFERENCE_SUFFIX                                              NaN
# REFERENCE_ROAD_NAME                                           NaN
# LATITUDE                                                39.282928
# LONGITUDE                                              -76.635215
# LOCATION               POINT (-76.6352150952347 39.2829284750108)
#
#                                                         4
# YEAR                                                 2020
# QUARTER                                                Q2
# LIGHT_DESC                                       Daylight
# LIGHT_CODE                                            1.0
# COUNTY_DESC                                         Cecil
# COUNTY_NO                                             7.0
# MUNI_DESC                                             NaN
# MUNI_CODE                                             NaN
# JUNCTION_DESC                                         NaN
# JUNCTION_CODE                                         NaN
# COLLISION_TYPE_DESC               Same Direction Rear End
# COLLISION_TYPE_CODE                                     3
# SURF_COND_DESC                                        NaN
# SURF_COND_CODE                                        NaN
# LANE_DESC                                             NaN
# LANE_CODE                                             NaN
# RD_COND_DESC                                          NaN
# RD_COND_CODE                                          NaN
# RD_DIV_DESC                                           NaN
# RD_DIV_CODE                                           NaN
# FIX_OBJ_DESC                               Not Applicable
# FIX_OBJ_CODE                                          0.0
# REPORT_NO                                     MSP6709008R
# REPORT_TYPE                         Property Damage Crash
# WEATHER_DESC                                          NaN
# WEATHER_CODE                                         6.01
# ACC_DATE                                         20200414
# ACC_TIME                                         17:32:00
# LOC_CODE                                              NaN
# SIGNAL_FLAG_DESC                                       No
# SIGNAL_FLAG                                             N
# C_M_ZONE_FLAG                                           N
# AGENCY_CODE                                           MSP
# AREA_CODE                                             UNK
# HARM_EVENT_DESC1                            Other Vehicle
# HARM_EVENT_CODE1                                      1.0
# HARM_EVENT_DESC2                           Not Applicable
# HARM_EVENT_CODE2                                      0.0
# RTE_NO                                                NaN
# ROUTE_TYPE_CODE                                       NaN
# RTE_SUFFIX                                            NaN
# LOG_MILE                                              NaN
# LOGMILE_DIR_FLAG_DESC                                 NaN
# LOGMILE_DIR_FLAG                                      NaN
# MAINROAD_NAME                                         NaN
# DISTANCE                                              NaN
# FEET_MILES_FLAG_DESC                                  NaN
# FEET_MILES_FLAG                                       NaN
# DISTANCE_DIR_FLAG                                     NaN
# REFERENCE_NO                                          NaN
# REFERENCE_TYPE_CODE                                   NaN
# REFERENCE_SUFFIX                                      NaN
# REFERENCE_ROAD_NAME                                   NaN
# LATITUDE                                        39.611028
# LONGITUDE                                      -75.951314
# LOCATION               POINT (-75.951314 39.611027833333)

# %%
persons.head().T
# Out:
#                                                        0  \
# Unnamed: 0                                             0
# SEX_DESC                                          Female
# SEX_CODE                                               F
# CONDITION_DESC                         Apparently Normal
# CONDITION_CODE                                       1.0
# INJ_SEVER_DESC                                 No Injury
# INJ_SEVER_CODE                                         1
# REPORT_NO                                     AE59920005
# PERSON_TYPE_DESC                                  Driver
# PERSON_TYPE                                            D
# ALCOHOL_TEST_DESC                         Not Applicable
# ALCOHOL_TEST_CODE                                    0.0
# DRUG_TEST_DESC                            Not Applicable
# DRUG_TEST_CODE                                       0.0
# FAULT_FLAG_DESC                                    False
# FAULT_FLAG                                             N
# EQUIP_PROB_DESC                           Not Applicable
# EQUIP_PROB_CODE                                      0.0
# SAF_EQUIP_DESC                            Not Applicable
# SAF_EQUIP_CODE                                       0.0
# EJECT_DESC                                Not Applicable
# EJECT_CODE                                           0.0
# DATE_OF_BIRTH                                   19901109
# PERSON_ID           53cfb29a-b39b-4af2-85df-cf88d7215e79
# LICENSE_STATE_CODE                                    MD
# CLASS                                                  C
# CDL_FLAG_DESC                                      False
# CDL_FLAG                                           False
# VEHICLE_ID          eacd0575-64e1-44f9-bd53-16449620c109
# AIRBAG_DEPLOYED                                      0.0
# YEAR                                                2017
# Quarter                                               Q2
#
#                                                        1  \
# Unnamed: 0                                             1
# SEX_DESC                                            Male
# SEX_CODE                                               M
# CONDITION_DESC                                       NaN
# CONDITION_CODE                                       NaN
# INJ_SEVER_DESC                 Non-incapacitating Injury
# INJ_SEVER_CODE                                         2
# REPORT_NO                                     DA40650004
# PERSON_TYPE_DESC                                Occupant
# PERSON_TYPE                                            O
# ALCOHOL_TEST_DESC                                    NaN
# ALCOHOL_TEST_CODE                                    NaN
# DRUG_TEST_DESC                                       NaN
# DRUG_TEST_CODE                                       NaN
# FAULT_FLAG_DESC                                      NaN
# FAULT_FLAG                                           NaN
# EQUIP_PROB_DESC                           Not Applicable
# EQUIP_PROB_CODE                                      0.0
# SAF_EQUIP_DESC                      Shoulder/Lap Belt(s)
# SAF_EQUIP_CODE                                      13.0
# EJECT_DESC                           Not Ejected/Trapped
# EJECT_CODE                                           1.0
# DATE_OF_BIRTH                                   19940925
# PERSON_ID           cb90b978-e091-4422-9ead-684355d3f4a8
# LICENSE_STATE_CODE                                   NaN
# CLASS                                                NaN
# CDL_FLAG_DESC                                        NaN
# CDL_FLAG                                             NaN
# VEHICLE_ID          ac456b44-041f-4a85-bedd-1a75fd5ff81a
# AIRBAG_DEPLOYED                                      1.0
# YEAR                                                2017
# Quarter                                               Q2
#
#                                                        2  \
# Unnamed: 0                                             2
# SEX_DESC                                          Female
# SEX_CODE                                               F
# CONDITION_DESC                                       NaN
# CONDITION_CODE                                       NaN
# INJ_SEVER_DESC            Possible Incapacitating Injury
# INJ_SEVER_CODE                                         3
# REPORT_NO                                     ZU7729000P
# PERSON_TYPE_DESC                                Occupant
# PERSON_TYPE                                            O
# ALCOHOL_TEST_DESC                                    NaN
# ALCOHOL_TEST_CODE                                    NaN
# DRUG_TEST_DESC                                       NaN
# DRUG_TEST_CODE                                       NaN
# FAULT_FLAG_DESC                                      NaN
# FAULT_FLAG                                           NaN
# EQUIP_PROB_DESC                                No Misuse
# EQUIP_PROB_CODE                                      1.0
# SAF_EQUIP_DESC                      Shoulder/Lap Belt(s)
# SAF_EQUIP_CODE                                      13.0
# EJECT_DESC                           Not Ejected/Trapped
# EJECT_CODE                                           1.0
# DATE_OF_BIRTH                                  09-JUL-94
# PERSON_ID           c56e2fdd-fa91-4d49-bae9-aa1e9b51efbd
# LICENSE_STATE_CODE                                   NaN
# CLASS                                                NaN
# CDL_FLAG_DESC                                        NaN
# CDL_FLAG                                             NaN
# VEHICLE_ID          1b1906ca-09cb-4018-9273-9f215cb5d5d3
# AIRBAG_DEPLOYED                                      1.0
# YEAR                                                2016
# Quarter                                               Q2
#
#                                                        3  \
# Unnamed: 0                                             3
# SEX_DESC                                            Male
# SEX_CODE                                               M
# CONDITION_DESC                                       NaN
# CONDITION_CODE                                       NaN
# INJ_SEVER_DESC                                 No Injury
# INJ_SEVER_CODE                                         1
# REPORT_NO                                     CT8278002X
# PERSON_TYPE_DESC                                Occupant
# PERSON_TYPE                                            O
# ALCOHOL_TEST_DESC                                    NaN
# ALCOHOL_TEST_CODE                                    NaN
# DRUG_TEST_DESC                                       NaN
# DRUG_TEST_CODE                                       NaN
# FAULT_FLAG_DESC                                      NaN
# FAULT_FLAG                                           NaN
# EQUIP_PROB_DESC                                No Misuse
# EQUIP_PROB_CODE                                      1.0
# SAF_EQUIP_DESC                      Shoulder/Lap Belt(s)
# SAF_EQUIP_CODE                                      13.0
# EJECT_DESC                           Not Ejected/Trapped
# EJECT_CODE                                           1.0
# DATE_OF_BIRTH                                   20090921
# PERSON_ID           aa15e7f7-e40e-4fdb-aedb-a966c71c7bc8
# LICENSE_STATE_CODE                                   NaN
# CLASS                                                NaN
# CDL_FLAG_DESC                                        NaN
# CDL_FLAG                                             NaN
# VEHICLE_ID          1cd6afef-9669-41a2-acd2-dee9af76f2c4
# AIRBAG_DEPLOYED                                      1.0
# YEAR                                                2018
# Quarter                                               Q3
#
#                                                        4
# Unnamed: 0                                             4
# SEX_DESC                                          Female
# SEX_CODE                                               F
# CONDITION_DESC                         Apparently Normal
# CONDITION_CODE                                       1.0
# INJ_SEVER_DESC                                 No Injury
# INJ_SEVER_CODE                                         1
# REPORT_NO                                     DA3660000B
# PERSON_TYPE_DESC                                  Driver
# PERSON_TYPE                                            D
# ALCOHOL_TEST_DESC                         Not Applicable
# ALCOHOL_TEST_CODE                                    0.0
# DRUG_TEST_DESC                            Not Applicable
# DRUG_TEST_CODE                                       0.0
# FAULT_FLAG_DESC                                     True
# FAULT_FLAG                                             Y
# EQUIP_PROB_DESC                                No Misuse
# EQUIP_PROB_CODE                                      1.0
# SAF_EQUIP_DESC                      Shoulder/Lap Belt(s)
# SAF_EQUIP_CODE                                      13.0
# EJECT_DESC                           Not Ejected/Trapped
# EJECT_CODE                                           1.0
# DATE_OF_BIRTH                                  12-JAN-56
# PERSON_ID           80375a09-f4bb-4d11-88c6-c399bafcc693
# LICENSE_STATE_CODE                                    DC
# CLASS                                                NaN
# CDL_FLAG_DESC                                      False
# CDL_FLAG                                           False
# VEHICLE_ID          b5e6a3b9-7e40-4d2d-98e9-ed32dee9a90c
# AIRBAG_DEPLOYED                                      NaN
# YEAR                                                2015
# Quarter                                               Q2

# %%
vehicles.head().T
# Out:
#                                                               0  \
# Unnamed: 0                                                    1
# HARM_EVENT_DESC                                   Other Vehicle
# CONTI_DIRECTION_DESC                                      North
# DAMAGE_DESC                                         Superficial
# MOVEMENT_DESC                             Moving Constant Speed
# VIN_NO                                        NMTKHMBX0JR025092
# REPORT_NO                                           MSP7221001P
# VEH_YEAR                                                   2018
# VEH_MAKE                                                 TOYOTA
# COMMERCIAL_FLAG_DESC                                         No
# TOWED_AWAY_FLAG_DESC                                         No
# GOING_DIRECTION_DESC                                      North
# BODY_TYPE_DESC                                    Passenger Car
# DRIVERLESS_FLAG_DESC                                         No
# FIRE_FLAG_DESC                                               No
# PARKED_FLAG_DESC                                             No
# SPEED_LIMIT                                                  55
# HIT_AND_RUN_FLAG_DESC                                        No
# VEHICLE_ID                 0dbd4a00-c7f2-4c34-b543-c2633fe0118f
# TOWED_VEHICLE_CONFIG_DESC                        Not Applicable
# YEAR                                                       2020
# Quarter                                                      Q2
#
#                                                               1  \
# Unnamed: 0                                                    2
# HARM_EVENT_DESC                                   Other Vehicle
# CONTI_DIRECTION_DESC                                      South
# DAMAGE_DESC                                          Functional
# MOVEMENT_DESC                           Stopped in Traffic Lane
# VIN_NO                                        2GNAXPEX5K6103012
# REPORT_NO                                            DA37010040
# VEH_YEAR                                                   2019
# VEH_MAKE                                              CHEVROLET
# COMMERCIAL_FLAG_DESC                                         No
# TOWED_AWAY_FLAG_DESC                                         No
# GOING_DIRECTION_DESC                                      South
# BODY_TYPE_DESC                          (Sport) Utility Vehicle
# DRIVERLESS_FLAG_DESC                                         No
# FIRE_FLAG_DESC                                               No
# PARKED_FLAG_DESC                                             No
# SPEED_LIMIT                                                  30
# HIT_AND_RUN_FLAG_DESC                                        No
# VEHICLE_ID                 f2c0d05c-ff70-4549-9d48-57c182eae6f2
# TOWED_VEHICLE_CONFIG_DESC                        Not Applicable
# YEAR                                                       2020
# Quarter                                                      Q2
#
#                                                               2  \
# Unnamed: 0                                                    4
# HARM_EVENT_DESC                                   Other Vehicle
# CONTI_DIRECTION_DESC                                       East
# DAMAGE_DESC                                           Disabling
# MOVEMENT_DESC                               Slowing or Stopping
# VIN_NO                                        5FNRL18672B048550
# REPORT_NO                                            AE456100BL
# VEH_YEAR                                                   2002
# VEH_MAKE                                                  HONDA
# COMMERCIAL_FLAG_DESC                                         No
# TOWED_AWAY_FLAG_DESC                                        Yes
# GOING_DIRECTION_DESC                                       East
# BODY_TYPE_DESC                                    Passenger Car
# DRIVERLESS_FLAG_DESC                                         No
# FIRE_FLAG_DESC                                               No
# PARKED_FLAG_DESC                                             No
# SPEED_LIMIT                                                  35
# HIT_AND_RUN_FLAG_DESC                                        No
# VEHICLE_ID                 23d968b0-be0e-4810-b6f0-34ef33fd7112
# TOWED_VEHICLE_CONFIG_DESC                        Not Applicable
# YEAR                                                       2020
# Quarter                                                      Q2
#
#                                                               3  \
# Unnamed: 0                                                    5
# HARM_EVENT_DESC                                   Other Vehicle
# CONTI_DIRECTION_DESC                                        NaN
# DAMAGE_DESC                                          Functional
# MOVEMENT_DESC                                            Parked
# VIN_NO                                        1ZVHT80N995109297
# REPORT_NO                                            AE5919007M
# VEH_YEAR                                                   2009
# VEH_MAKE                                                   FORD
# COMMERCIAL_FLAG_DESC                                         No
# TOWED_AWAY_FLAG_DESC                                         No
# GOING_DIRECTION_DESC                                        NaN
# BODY_TYPE_DESC                                    Passenger Car
# DRIVERLESS_FLAG_DESC                                        Yes
# FIRE_FLAG_DESC                                               No
# PARKED_FLAG_DESC                                            Yes
# SPEED_LIMIT                                                   0
# HIT_AND_RUN_FLAG_DESC                                        No
# VEHICLE_ID                 06d30f00-e7b0-4be6-a296-c88272e2439e
# TOWED_VEHICLE_CONFIG_DESC                        Not Applicable
# YEAR                                                       2020
# Quarter                                                      Q2
#
#                                                               4
# Unnamed: 0                                                    6
# HARM_EVENT_DESC                                   Other Vehicle
# CONTI_DIRECTION_DESC                                       West
# DAMAGE_DESC                                          Functional
# MOVEMENT_DESC                             Moving Constant Speed
# VIN_NO                                        19XFC1F49HE213193
# REPORT_NO                                            ADJ778001H
# VEH_YEAR                                                   2017
# VEH_MAKE                                                   HOND
# COMMERCIAL_FLAG_DESC                                         No
# TOWED_AWAY_FLAG_DESC                                         No
# GOING_DIRECTION_DESC                                       West
# BODY_TYPE_DESC                                    Passenger Car
# DRIVERLESS_FLAG_DESC                                         No
# FIRE_FLAG_DESC                                               No
# PARKED_FLAG_DESC                                             No
# SPEED_LIMIT                                                  25
# HIT_AND_RUN_FLAG_DESC                                        No
# VEHICLE_ID                 5be2e6f2-4b9c-4ede-b442-b4d1a6e82e72
# TOWED_VEHICLE_CONFIG_DESC                        Not Applicable
# YEAR                                                       2020
# Quarter                                                      Q2

# %%
crashes.shape
# Out:
# (715561, 56)

# %%
persons.shape
# Out:
# (1664889, 32)

# %%
vehicles.shape
# Out:
# (1162313, 22)

# %%
crashes.columns
# Out:
# Index(['YEAR', 'QUARTER', 'LIGHT_DESC', 'LIGHT_CODE', 'COUNTY_DESC',
#        'COUNTY_NO', 'MUNI_DESC', 'MUNI_CODE', 'JUNCTION_DESC', 'JUNCTION_CODE',
#        'COLLISION_TYPE_DESC', 'COLLISION_TYPE_CODE', 'SURF_COND_DESC',
#        'SURF_COND_CODE', 'LANE_DESC', 'LANE_CODE', 'RD_COND_DESC',
#        'RD_COND_CODE', 'RD_DIV_DESC', 'RD_DIV_CODE', 'FIX_OBJ_DESC',
#        'FIX_OBJ_CODE', 'REPORT_NO', 'REPORT_TYPE', 'WEATHER_DESC',
#        'WEATHER_CODE', 'ACC_DATE', 'ACC_TIME', 'LOC_CODE', 'SIGNAL_FLAG_DESC',
#        'SIGNAL_FLAG', 'C_M_ZONE_FLAG', 'AGENCY_CODE', 'AREA_CODE',
#        'HARM_EVENT_DESC1', 'HARM_EVENT_CODE1', 'HARM_EVENT_DESC2',
#        'HARM_EVENT_CODE2', 'RTE_NO', 'ROUTE_TYPE_CODE', 'RTE_SUFFIX',
#        'LOG_MILE', 'LOGMILE_DIR_FLAG_DESC', 'LOGMILE_DIR_FLAG',
#        'MAINROAD_NAME', 'DISTANCE', 'FEET_MILES_FLAG_DESC', 'FEET_MILES_FLAG',
#        'DISTANCE_DIR_FLAG', 'REFERENCE_NO', 'REFERENCE_TYPE_CODE',
#        'REFERENCE_SUFFIX', 'REFERENCE_ROAD_NAME', 'LATITUDE', 'LONGITUDE',
#        'LOCATION'],
#       dtype='object')

# %%
vehicles.columns
# Out:
# Index(['Unnamed: 0', 'HARM_EVENT_DESC', 'CONTI_DIRECTION_DESC', 'DAMAGE_DESC',
#        'MOVEMENT_DESC', 'VIN_NO', 'REPORT_NO', 'VEH_YEAR', 'VEH_MAKE',
#        'COMMERCIAL_FLAG_DESC', 'TOWED_AWAY_FLAG_DESC', 'GOING_DIRECTION_DESC',
#        'BODY_TYPE_DESC', 'DRIVERLESS_FLAG_DESC', 'FIRE_FLAG_DESC',
#        'PARKED_FLAG_DESC', 'SPEED_LIMIT', 'HIT_AND_RUN_FLAG_DESC',
#        'VEHICLE_ID', 'TOWED_VEHICLE_CONFIG_DESC', 'YEAR', 'Quarter'],
#       dtype='object')

# %%
persons.columns
# Out:
# Index(['Unnamed: 0', 'SEX_DESC', 'SEX_CODE', 'CONDITION_DESC',
#        'CONDITION_CODE', 'INJ_SEVER_DESC', 'INJ_SEVER_CODE', 'REPORT_NO',
#        'PERSON_TYPE_DESC', 'PERSON_TYPE', 'ALCOHOL_TEST_DESC',
#        'ALCOHOL_TEST_CODE', 'DRUG_TEST_DESC', 'DRUG_TEST_CODE',
#        'FAULT_FLAG_DESC', 'FAULT_FLAG', 'EQUIP_PROB_DESC', 'EQUIP_PROB_CODE',
#        'SAF_EQUIP_DESC', 'SAF_EQUIP_CODE', 'EJECT_DESC', 'EJECT_CODE',
#        'DATE_OF_BIRTH', 'PERSON_ID', 'LICENSE_STATE_CODE', 'CLASS',
#        'CDL_FLAG_DESC', 'CDL_FLAG', 'VEHICLE_ID', 'AIRBAG_DEPLOYED', 'YEAR',
#        'Quarter'],
#       dtype='object')

# %% [markdown]
# ### Removing Unnamed columns

# %%
persons = persons.drop('Unnamed: 0', axis = 1)
vehicles = vehicles.drop('Unnamed: 0', axis = 1)

# %% [markdown]
# ### Merging the three datasets on the common column 'REPORT_NO'

# %%
#Choose column names based on your needs.
crashes_df=crashes[['ACC_DATE', 'ACC_TIME','WEATHER_DESC','REPORT_NO','COUNTY_DESC','LATITUDE', 'LONGITUDE','SURF_COND_DESC', 'RD_COND_DESC',
       'RD_DIV_DESC']]
persons_df=persons[['REPORT_NO','SEX_DESC','DATE_OF_BIRTH','INJ_SEVER_DESC']]
vehicles_df=vehicles[['VEH_YEAR', 'VEH_MAKE','REPORT_NO','SPEED_LIMIT','YEAR','Quarter']]

# %%
# merging crashes and persons
final_data = pd.merge(pd.merge(crashes_df,persons_df,on="REPORT_NO"),vehicles_df,on="REPORT_NO")
final_data.head()
# Out:
#    ACC_DATE  ACC_TIME    WEATHER_DESC   REPORT_NO     COUNTY_DESC   LATITUDE  \
# 0  20200618  15:15:00  Not Applicable  AE58770052       Baltimore  39.277263
# 1  20200430  06:39:00             NaN  ADJ984001J  Baltimore City  39.311025
# 2  20200430  06:39:00             NaN  ADJ984001J  Baltimore City  39.311025
# 3  20200430  06:39:00             NaN  ADJ984001J  Baltimore City  39.311025
# 4  20200430  06:39:00             NaN  ADJ984001J  Baltimore City  39.311025
#
#    LONGITUDE SURF_COND_DESC RD_COND_DESC         RD_DIV_DESC SEX_DESC  \
# 0 -76.503693            NaN          NaN                 NaN      NaN
# 1 -76.616429            Dry   No Defects  One-way Trafficway     Male
# 2 -76.616429            Dry   No Defects  One-way Trafficway     Male
# 3 -76.616429            Dry   No Defects  One-way Trafficway     Male
# 4 -76.616429            Dry   No Defects  One-way Trafficway      NaN
#
#   DATE_OF_BIRTH                  INJ_SEVER_DESC  VEH_YEAR VEH_MAKE  \
# 0           NaN                       No Injury      2019      TOY
# 1      19750621  Possible Incapacitating Injury      2005  HYUNDAI
# 2      19750621  Possible Incapacitating Injury      2014     SUBA
# 3      19750621  Possible Incapacitating Injury      2015     VOLK
# 4           NaN                       No Injury      2005  HYUNDAI
#
#    SPEED_LIMIT  YEAR Quarter
# 0            5  2020      Q2
# 1           45  2020      Q2
# 2           30  2020      Q2
# 3           30  2020      Q2
# 4           45  2020      Q2

# %%
final_data.columns
# Out:
# Index(['ACC_DATE', 'ACC_TIME', 'WEATHER_DESC', 'REPORT_NO', 'COUNTY_DESC',
#        'LATITUDE', 'LONGITUDE', 'SURF_COND_DESC', 'RD_COND_DESC',
#        'RD_DIV_DESC', 'SEX_DESC', 'DATE_OF_BIRTH', 'INJ_SEVER_DESC',
#        'VEH_YEAR', 'VEH_MAKE', 'SPEED_LIMIT', 'YEAR', 'Quarter'],
#       dtype='object')

# %%
final_data.describe()
# Out:
#            ACC_DATE      LATITUDE     LONGITUDE      VEH_YEAR   SPEED_LIMIT  \
# count  2.950459e+06  2.950459e+06  2.950459e+06  2.950459e+06  2.950459e+06
# mean   2.017782e+07  3.913909e+01 -7.674458e+01  2.010270e+03  3.602871e+01
# std    1.807563e+04  3.028203e-01  4.446217e-01  5.225548e+00  1.525455e+01
# min    2.015010e+07  3.700000e+01 -7.999610e+01  2.000000e+03  0.000000e+00
# 25%    2.016092e+07  3.898114e+01 -7.694194e+01  2.006000e+03  2.500000e+01
# 50%    2.018032e+07  3.920242e+01 -7.671798e+01  2.011000e+03  3.500000e+01
# 75%    2.019091e+07  3.933824e+01 -7.658360e+01  2.015000e+03  5.000000e+01
# max    2.021063e+07  3.999480e+01 -7.500000e+01  2.021000e+03  7.500000e+01
#
#                YEAR
# count  2.950459e+06
# mean   2.017715e+03
# std    1.811540e+00
# min    2.015000e+03
# 25%    2.016000e+03
# 50%    2.018000e+03
# 75%    2.019000e+03
# max    2.021000e+03

# %% [markdown]
# ## Sanity Checks

# %%
final_data['REPORT_NO'].value_counts().sort_values()
# Out:
# AE5090000C         1
# AE45380033         1
# MSP67870029        1
# ZK01130025         1
# MSP58400057        1
#                 ...
# MSP6063006C      345
# MSP67460095      360
# CE4636002C       480
# CB53480003      1221
# MDTA1229000H    5508
# Name: REPORT_NO, Length: 676884, dtype: int64

# %%
# Using REPORT_NO, removing duplicates that aren't needed.
final_df=final_data.drop_duplicates(subset="REPORT_NO",keep='first')

# %%
final_df['REPORT_NO'].value_counts().sort_values()
# Out:
# AE58770052     1
# ADJ9740010     1
# EJ7878001D     1
# ADI7910042     1
# MSP6709008R    1
#               ..
# MSP691200HR    1
# DA4247000J     1
# ZVW273000J     1
# ADJ203005N     1
# AE5414003H     1
# Name: REPORT_NO, Length: 676884, dtype: int64

# %%
final_df.hist(figsize=(20,20))
plt.show()

# %%
final_df['DATE_OF_BIRTH']=pd.to_datetime(final_df['DATE_OF_BIRTH'], errors='coerce')
final_df['DOB_YEAR'] = final_df['DATE_OF_BIRTH'].dt.year

# %%
# Calculating the age of a person and storing it in a new variable (column)
final_df['AGE']=2022-final_df['DOB_YEAR']

# %%
#Storing accident date into correct format
final_df['accident_date']=pd.to_datetime(final_df['ACC_DATE'],format='%Y%m%d')

# %%
#Storing accident date time into correct format
final_df['accident_datetime']=pd.to_datetime(final_df['accident_date'].astype(str)+' '+final_df['ACC_TIME'].astype(str))

# %%
final_df.head()
# Out:
#     ACC_DATE  ACC_TIME    WEATHER_DESC    REPORT_NO     COUNTY_DESC  \
# 0   20200618  15:15:00  Not Applicable   AE58770052       Baltimore
# 1   20200430  06:39:00             NaN   ADJ984001J  Baltimore City
# 19  20200504  09:46:00             NaN   EJ7878001D      Montgomery
# 21  20170507  10:39:00           Other   ADI7910042  Baltimore City
# 23  20200414  17:32:00             NaN  MSP6709008R           Cecil
#
#      LATITUDE  LONGITUDE SURF_COND_DESC RD_COND_DESC         RD_DIV_DESC  ...  \
# 0   39.277263 -76.503693            NaN          NaN                 NaN  ...
# 1   39.311025 -76.616429            Dry   No Defects  One-way Trafficway  ...
# 19  39.140680 -77.193413            NaN          NaN                 NaN  ...
# 21  39.282928 -76.635215            NaN          NaN                 NaN  ...
# 23  39.611028 -75.951314            NaN          NaN                 NaN  ...
#
#                     INJ_SEVER_DESC VEH_YEAR VEH_MAKE  SPEED_LIMIT  YEAR  \
# 0                        No Injury     2019      TOY            5  2020
# 1   Possible Incapacitating Injury     2005  HYUNDAI           45  2020
# 19       Non-incapacitating Injury     2020    CHEVY            0  2020
# 21  Possible Incapacitating Injury     2009   TOYOTA            0  2017
# 23                       No Injury     2007      KIA            5  2020
#
#     Quarter  DOB_YEAR   AGE  accident_date   accident_datetime
# 0        Q2       NaN   NaN     2020-06-18 2020-06-18 15:15:00
# 1        Q2    1975.0  47.0     2020-04-30 2020-04-30 06:39:00
# 19       Q2    1957.0  65.0     2020-05-04 2020-05-04 09:46:00
# 21       Q2    1955.0  67.0     2017-05-07 2017-05-07 10:39:00
# 23       Q2    1982.0  40.0     2020-04-14 2020-04-14 17:32:00
#
# [5 rows x 22 columns]

# %%
final_df.isna().sum()
# Out:
# ACC_DATE                  0
# ACC_TIME                  0
# WEATHER_DESC         285636
# REPORT_NO                 0
# COUNTY_DESC               7
# LATITUDE                  0
# LONGITUDE                 0
# SURF_COND_DESC        67722
# RD_COND_DESC          65755
# RD_DIV_DESC           69507
# SEX_DESC              72919
# DATE_OF_BIRTH         74490
# INJ_SEVER_DESC            0
# VEH_YEAR                  0
# VEH_MAKE                 45
# SPEED_LIMIT               0
# YEAR                      0
# Quarter                   0
# DOB_YEAR              74490
# AGE                   74490
# accident_date             0
# accident_datetime         0
# dtype: int64

# %% [markdown]
# ### Drop Null values

# %%
final_df=final_df.dropna()

# %%
final_df.isna().sum()
# Out:
# ACC_DATE             0
# ACC_TIME             0
# WEATHER_DESC         0
# REPORT_NO            0
# COUNTY_DESC          0
# LATITUDE             0
# LONGITUDE            0
# SURF_COND_DESC       0
# RD_COND_DESC         0
# RD_DIV_DESC          0
# SEX_DESC             0
# DATE_OF_BIRTH        0
# INJ_SEVER_DESC       0
# VEH_YEAR             0
# VEH_MAKE             0
# SPEED_LIMIT          0
# YEAR                 0
# Quarter              0
# DOB_YEAR             0
# AGE                  0
# accident_date        0
# accident_datetime    0
# dtype: int64

# %% [markdown]
# ### Removing records where speed limit is 0

# %%
final_df=final_df[final_df['SPEED_LIMIT']>0]

# %% [markdown]
# ### Removing records where WEATHER_DESC is Not applicable, Unknown, Other, Null

# %%
final_df=final_df[(final_df.WEATHER_DESC != 'Not Applicable') \
                                  & (final_df.WEATHER_DESC != 'Unknown') \
                                  & (final_df.WEATHER_DESC != 'Other') \
                                  & (final_df.WEATHER_DESC != 'null')]

# %% [markdown]
# ### Removing records where RD_COND_DESC is Not applicable

# %%
final_df=final_df[(final_df.RD_COND_DESC != 'Not Applicable')]

# %% [markdown]
# ### Removing records where SURF_COND_DESC is Not applicable

# %%
final_df=final_df[(final_df.SURF_COND_DESC != 'Not Applicable')]

# %% [markdown]
# ### Correlation map of different columns specified

# %%
sns.heatmap(data=final_df[['SPEED_LIMIT','AGE','YEAR']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Highest accidents recorded among county in different years

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=final_df, x='YEAR',color='steelblue')
plt.show()

# %% [markdown]
# - The number of crashes reported in the years 2017, 2018, and 2019 has decreased. This might be a result of the pandemic's travel restrictions and lockdowns.

# %% [markdown]
# ### Crashes recorded on different quarters of years in different year

# %%
plt.figure()
fig1 = sns.catplot(data = final_df, x = 'YEAR', kind = 'count', hue ='Quarter', height = 6, aspect = 2,color='steelblue')
plt.show()

# %% [markdown]
# - According to the above plot's conclusion, up until 2020, the fourth quarter of the year saw the majority of accidents, and in the same quarter in 2021, there were none.

# %% [markdown]
# ### Crashes recorded on different months of year

# %%
final_df['Month'] = final_df['accident_date'].dt.month_name()

# %%
months=final_df['accident_datetime'].dt.month_name().value_counts()

ax = months.plot(kind='bar', figsize=(10,5),color='steelblue')
ax.set(xlabel='Month', ylabel='Total crashes', title='Month wise accidents records')
ax.plot()
# Out:
# []

# %% [markdown]
#
# - We can see from the visualization above that October saw the most accidents overall.
#
# - After the spring, the curve progressively declines, and the count is lower in the summer.
#
# - We can analyse that in spring there are more accidents took place due to the rain, ice and fog.

# %% [markdown]
# ### Accidents occured on day of week

# %%
days = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
final_df['dayOfWeek'] = final_df['accident_date'].dt.dayofweek
final_df['dayOfWeek'] = final_df['dayOfWeek'].apply(lambda x: days[x])

# %%
days=final_df['accident_date'].dt.day_name().value_counts()

ax = days.plot(kind='bar', figsize=(10,5),color='steelblue')
ax.set(xlabel='Days', ylabel='Total records', title='Day wise accidents records')
ax.plot()
# Out:
# []

# %% [markdown]
# - According to the above graph, the count is higher on Thursdays and Fridays.
#
# - We can see that there is a lot of traffic during the working days, and the chances of a crash are also high.

# %% [markdown]
# ### Accidents occured on hour of the day

# %%
final_df['Hour'] = final_df['accident_datetime'].dt.hour

# %%
hours=final_df['accident_datetime'].dt.hour.value_counts()

ax = hours.plot(kind='bar',  figsize=(10,5), fontsize=12,color='steelblue')
ax.set(xlabel='Hours', ylabel='Total records', title='Hour wise accidents records')
ax.plot()
# Out:
# []

# %% [markdown]
#
# - According to the above visualization, the more accidents occur between the hours of 15 and 20.
#
# - We can analyse that the count of accidents is more at night due to the less visibility the distance is hard to judge at night times.

# %% [markdown]
# ### Analyzing crashes on any time of day

# %%
plt.figure(figsize = (25,10))
sns.set_theme(style="whitegrid")
sns.countplot(x = 'dayOfWeek',hue = 'Hour',data = final_df)
plt.show()

# %% [markdown]
# - We can see from the plot above that there are more accidents between 3 and 9 p.m. and between 6 and 10 a.m. We can conclude that it is likely due to heavy traffic during office hours.
# - Sundays and Saturdays have the fewest accidents because there is less traffic on the weekends.

# %% [markdown]
# ### Analyzing crashes on any month of year

# %%
plt.figure(figsize = (25,10))
sns.set_theme(style="whitegrid")
ax = sns.countplot(x = 'YEAR',hue = 'Month',data = final_df)
plt.show()

# %% [markdown]
# - The majority of accidents occurred during the first five months of the year, which could be attributed to ice, fog, and cold.

# %% [markdown]
# ###  Crashes for each shift of day

# %%
final_df['Hour'] = final_df['Hour'].astype(str).astype(int)
final_df['accident_shift'] = np.where((final_df['Hour'] >= 6) & (final_df['Hour']<11), 'Morning',
                        np.where((final_df['Hour'] >= 11) & (final_df['Hour']<15), 'Noon',
                               np.where((final_df['Hour'] >= 15) & (final_df['Hour']<18),'Afternoon','Evening')))

# %%
x = final_df['accident_shift'].value_counts().index
y =final_df['accident_shift'].value_counts().values
plt.pie(y,labels=x, autopct = '%1.1f%%', colors = sns.color_palette('Set2'))
plt.title("Total accident occured on different shift of day")
fig =  plt.gcf()
plt.show()

# %% [markdown]
# ### Crashes occured on according to season

# %%
final_df['season'] = (final_df['accident_date'].dt.month%12 + 3)//3
seasons = {
             1: 'Winter',
             2: 'Spring',
             3: 'Summer',
             4: 'Autumn'
}
final_df['season_name'] = final_df['season'].map(seasons)

# %%
x = final_df['season_name'].value_counts().index
y =final_df['season_name'].value_counts().values

plt.pie(y,labels=x, pctdistance=0.9,autopct = '%1.1f%%', colors = sns.color_palette('Set2'))
plt.title("Total accident occured on different season of year")
fig = plt.gcf()
plt.show()

# %% [markdown]
# ###  Analysis on county with maximum number of crashes

# %%
plt.figure()
fig1 = sns.displot(data = crashes, x = 'COUNTY_DESC', kind = 'hist', height = 6, aspect = 2,color='steelblue')
fig1.set_xticklabels(rotation = 90)
plt.show()

# %% [markdown]
# - The county with the most reported crashes is Baltimore.

# %% [markdown]
# ### Road divisions in Baltimore

# %%
baltimore_data = final_df[final_df['COUNTY_DESC'] == 'Baltimore']

# %%
road_div = baltimore_data['RD_DIV_DESC'].value_counts()
legend = road_div.index
fig, ax = plt.subplots(figsize = (5,5))
plt.pie(road_div.values,colors=sns.color_palette('Set2'),autopct='%.0f%%')
ax.legend(legend,bbox_to_anchor=(1.05, 1),loc='upper left', borderaxespad=0)
plt.title("Road division in Baltimore county")
plt.show()

# %% [markdown]
# - In this case, the road division in the category of two-way not divided is greater than the other divisions. As there is no separation, vehicles may have taken the wrong path.

# %% [markdown]
# ### Crashes in accordance to surface condition

# %%
surface_cond = baltimore_data['SURF_COND_DESC'].value_counts()
legend = surface_cond.index
fig, ax = plt.subplots(figsize=(5,5))
plt.pie(surface_cond.values,colors=sns.color_palette('Set2'),autopct='%.0f%%')
ax.legend(legend,bbox_to_anchor=(1.05, 1),loc='upper left', borderaxespad=0)
plt.title("Surface Condition in Baltimore county")
plt.show()

# %% [markdown]
# - According to the plottings above, crashes in Baltimore County are caused by a two-sided road that is not divided in between.

# %% [markdown]
# ### Injuries caused by accidents

# %%
severity_plot = sns.countplot(data = final_df, x = 'COUNTY_DESC', hue = 'INJ_SEVER_DESC')
sns.set(rc = {'figure.figsize':(40,20)})
severity_plot.set_xticklabels(severity_plot.get_xticklabels(), rotation = 90, size=30,color='steelblue')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ### Analyzing  crashes based on weather description column.

# %%
plt.figure(figsize=(8,5))
ax = sns.countplot(y = final_df['WEATHER_DESC'],color='steelblue')
plt.title('Weather During the Vehicle Crash')
plt.xlabel('Count')
plt.ylabel('Weather')
plt.show()

# %% [markdown]
#
# - The number increases on rainy days because the roads are wet and there is a greater chance of a skid.

# %% [markdown]
# ### Plotting the top 10 vehicle types

# %%
NoOfCrashes=final_df.groupby(['VEH_MAKE'])['accident_date'].count()
NoOfCrashes=NoOfCrashes.sort_values(ascending=False)

# %%
NoOfCrashes=NoOfCrashes.head(10)
plt.figure(figsize=(11,7))
NoOfCrashes.plot(kind='barh', x='VEH_MAKE', y='count')
plt.title("Top 10 Vehicle types", fontdict = {'fontsize': 20,  'color': 'steelblue'})
plt.show()

# %% [markdown]
#
# - The majority of the accidents involved Ford vehicles.

# %% [markdown]
# ### Determing the average age of the drivers who were involved in these accidents for each county

# %%
avg_age=final_df.groupby(['COUNTY_DESC'])['AGE'].mean()
avg_age = round(avg_age,2)

# %%
fig, ax = plt.subplots(figsize=(30,10))
average_ages = np.array(avg_age.index)
ages = np.array(avg_age)
for index in range(len(average_ages)):
    ax.text(average_ages[index], ages[index], ages[index], size=10)   
plt.plot(average_ages,ages,marker='*', markerfacecolor='blue',markersize=6, color='steelblue', linewidth=4,label="value_count")
plt.xlabel("County")
plt.ylabel("Ages")
plt.xticks(rotation=90)
plt.title("Average age of people involved in accidents countywise")
plt.show()

# %% [markdown]
# ### Ploting data by year and month to get average  no of accidents per month

# %%
boxplot = final_df.groupby(['YEAR','Month'], as_index = False).size()
boxplot.rename(columns ={'size':'total_accidents'}, inplace = True)

# %%
sns.set(style='whitegrid')
sns.set(rc={"figure.figsize":(20,10)})
sns.boxplot(x="Month",y="total_accidents", data=boxplot, color='steelblue')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='total_accidents'>

# %% [markdown]
# ## Statistical Analysis

# %% [markdown]
# ### Applying Ztest on age and accidents occured and testing hypothesis

# %%
final_df['AGE'].describe()
# Out:
# count    244928.000000
# mean         40.278139
# std          21.411328
# min         -49.000000
# 25%          28.000000
# 50%          38.000000
# 75%          54.000000
# max         122.000000
# Name: AGE, dtype: float64

# %%
#taking random 60 persons age as data from original dataframe
data = final_df['AGE'].sample(60)

# %%
#from overall calculation of original data 
mu = 40.27
sigma = 21.41

# %%
#Testing hypothesis on accordance of 95% confidence interval
alpha = 0.05
null_mean = data.mean()

print('mean=%.2f stdv=%.2f' % (np.mean(data), np.std(data)))
# Out:
# mean=39.83 stdv=17.40

# %%
# now we perform the test. In this function, we passed data, in the value parameter
# we passed mean value in the null hypothesis, in alternative hypothesis we check whether the
# mean is larger
  
ztest_Score, p_value= ztest(data,value = null_mean, alternative='larger')

# %%
# the function outputs a p_value and z-score corresponding to that value, we compare the 
# p-value with alpha, if it is greater than alpha then we do not null hypothesis 
# else we reject it.
  
if(p_value <  alpha):
    print("Reject Null Hypothesis: The average age of people involved in accident is equals to 36. ")
else:
    print("Fail to Reject NUll Hypothesis: The average age of people involved in accident is less than 36.")
# Out:
# Fail to Reject NUll Hypothesis: The average age of people involved in accident is less than 36.
